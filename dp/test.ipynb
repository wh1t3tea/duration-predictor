# %%
import pandas as pd
data = pd.read_pickle("/Users/maksimmaslov/Downloads/durations_embeddings_librittsr_train_clean_100.pkl")

# %%
data[0]
# Out:
# {'id': '6836_61804_000004_000000.wav',
#  'speaker': '6836',
#  'text': 'though saddened by the series of tragedies so quickly transpiring, she was but human; and, being woman, who can blame her for giving way to the subdued happiness that succeeded?',
#  'phones': ['[SILENCE]',
#   'DH',
#   'OW0',
#   '[SILENCE]',
#   'S',
#   'AE0',
#   'D',
#   'AH0',
#   'N',
#   'D',
#   '[SILENCE]',
#   'B',
#   'AY0',
#   '[SILENCE]',
#   'DH',
#   'AH0',
#   '[SILENCE]',
#   'S',
#   'IH0',
#   'R',
#   'IY0',
#   'Z',
#   '[SILENCE]',
#   'AH0',
#   'V',
#   '[SILENCE]',
#   'T',
#   'R',
#   'AE0',
#   'JH',
#   'AH0',
#   'D',
#   'IY0',
#   'Z',
#   '[SILENCE]',
#   'S',
#   'OW0',
#   '[SILENCE]',
#   'K',
#   'W',
#   'IH0',
#   'K',
#   'L',
#   'IY0',
#   '[SILENCE]',
#   'T',
#   'R',
#   'AE0',
#   'N',
#   'S',
#   'P',
#   'AY0',
#   'EH1',
#   'IH0',
#   'NG',
#   '[COMMA]',
#   'SH',
#   'IY0',
#   '[SILENCE]',
#   'W',
#   'AH0',
#   'Z',
#   '[SILENCE]',
#   'B',
#   'AH0',
# ...
